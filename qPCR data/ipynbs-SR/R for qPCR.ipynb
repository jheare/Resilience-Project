# %%
# %load_ext rpy2.ipython

# %%
# %%R
# # Define the cars vector with 5 values
# cars <- c(1, 3, 6, 4, 9)
#
# # Graph the cars vector with all defaults
# plot(cars)

# %%
# %%R
# source("http://bioconductor.org/biocLite.R")
# biocLite("HTqPCR")
# Out:
# /Users/sr320/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: trying URL 'http://www.bioconductor.org/packages/3.0/bioc/bin/macosx/mavericks/contrib/3.1/BiocInstaller_1.16.5.tgz'
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/sr320/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Content type 'application/x-gzip'
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/sr320/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:  length 49923 bytes (48 Kb)
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/sr320/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: opened URL
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/sr320/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: =
# ...

# %%
# %%R
# browseVignettes("HTqPCR")
# Out:
# /Users/sr320/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: starting httpd help server ...
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/sr320/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:  done
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %% [markdown]
# <img src="http://eagle.fish.washington.edu/cnidarian/skitch/BMC_Genomics___Full_text___ReadqPCR_and_NormqPCR__R_packages_for_the_reading__quality_checking_and_normalisation_of_RT-qPCR_quantification_cycle__Cq__data_1B42FF07.png" alt="BMC_Genomics___Full_text___ReadqPCR_and_NormqPCR__R_packages_for_the_reading__quality_checking_and_normalisation_of_RT-qPCR_quantification_cycle__Cq__data_1B42FF07.png"/>

# %% [markdown]
# <img src="http://eagle.fish.washington.edu/cnidarian/skitch/www_biomedcentral_com_-_Figure_1B42FF2A.png" alt="www_biomedcentral_com_-_Figure_1B42FF2A.png"/>
